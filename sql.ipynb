# %% [markdown]
# ***
# # Testing SQL
# ***

# %%
# Module that sets paths
import path

path_data =     path.path_data
path_df =       path.path_df
path_output =   path.path_output
# Out:
# Le dossier « Dataframe » est existant
# Le dossier « Output » est existant
# Le dossier « Data » est existant
#
# c:\Users\Charles_tour\Documents\GitHub\car_sales_forecast\
# c:\Users\Charles_tour\Documents\GitHub\car_sales_forecast\Data\
# c:\Users\Charles_tour\Documents\GitHub\car_sales_forecast\Dataframe\
# c:\Users\Charles_tour\Documents\GitHub\car_sales_forecast\Output\

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
scrap_data = pd.read_hdf(path_df + 'scrap_data.h5')

# saaq2016 = pd.read_csv(path_data + 'vehicules-circulation-2016.csv')
# saaq2017 = pd.read_csv(path_data + 'vehicule-en-circulation-2017.csv')
# saaq2018 = pd.read_csv(path_data + 'vehicule-en-circulation-2018.csv')
# saaq2019 = pd.read_csv(path_data + 'vehicule-en-circulation-2019.csv')
# saaq2020 = pd.read_csv(path_data + 'vehicule-en-circulation-2020.csv')
# saaq2021 = pd.read_csv(path_data + 'vehicule-en-circulation-2021.csv')

df_unique = pd.read_hdf(path_df + 'df_unique.h5')

# %%
df_test = df_unique.head().copy()
df_test2 = df_test

# %%
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine

# Create database connection
db = mysql.connector.connect(
    user='root',
    password='Soleil24%',
    host='localhost',
)

# Create sql db
mycursor = db.cursor()
mycursor.execute("CREATE DATABASE IF NOT EXISTS df_unique")
mycursor.execute("USE df_unique")

# Put data in db
table_name = 'df_unique'
engine = create_engine('mysql+mysqlconnector://root:Soleil24%@localhost/df_unique')
df_unique.to_sql(table_name, con=engine, if_exists='replace', index=False)
db.close()
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mysql\connector\network.py:163, in NetworkBrokerPlain._send_pkt(self, sock, address, pkt)
#     162 try:
# --> 163     sock.sendall(pkt)
#     164 except IOError as err:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1237, in SSLSocket.sendall(self, data, flags)
#    1236 while count < amount:
# -> 1237     v = self.send(byte_view[count:])
#    1238     count += v
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1206, in SSLSocket.send(self, data, flags)
#    1203         raise ValueError(
#    1204             "non-zero flags not allowed in calls to send() on %s" %
# ...

# %%
from sqlalchemy import create_engine

# Specify the connection parameters, including connect_timeout
db_username = 'root'
db_password = 'Soleil24%'
db_host = 'localhost'
db_name = 'df_unique'

connection_args = {
    'user': db_username,
    'password': db_password,
    'host': db_host,
    'database': db_name,
    'connect_timeout': 3000  # Set the connection timeout in seconds
}

# Create the SQLAlchemy engine with connection options
engine = create_engine('mysql+mysqlconnector://', connect_args=connection_args)

df_unique.to_sql(table_name, con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mysql\connector\network.py:163, in NetworkBrokerPlain._send_pkt(self, sock, address, pkt)
#     162 try:
# --> 163     sock.sendall(pkt)
#     164 except IOError as err:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1237, in SSLSocket.sendall(self, data, flags)
#    1236 while count < amount:
# -> 1237     v = self.send(byte_view[count:])
#    1238     count += v
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1206, in SSLSocket.send(self, data, flags)
#    1203         raise ValueError(
#    1204             "non-zero flags not allowed in calls to send() on %s" %
# ...

# %%
import pymongo

# Specify the connection parameters
db_username = 'your_username'
db_password = 'your_password'
db_host = 'localhost'
db_port = 27017  # MongoDB default port
db_name = 'your_database_name'

# Create a MongoDB client with connection options
client = pymongo.MongoClient(host=db_host, port=db_port, username=db_username, password=db_password)

# Select the database
db = client[db_name]

# Specify the collection name
collection_name = 'your_collection_name'

# Insert data into the MongoDB collection
data_to_insert = df_unique.to_dict(orient='records')  
collection = db[collection_name]
collection.insert_many(data_to_insert)
